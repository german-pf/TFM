# %%
import pandas as pd
import numpy as np
import sklearn.preprocessing as prep
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima
# Cargamos el csv
train = pd.read_csv('btcusd_1-min_data.csv')

print(train.shape)

# Mostramos 10 registros al azar
train.sample(10)

#miro donde hay nulls si los hay
train.isna().sum()

filas_con_nulos = train[train.isnull().any(axis=1)]
print(filas_con_nulos)

train = train.dropna()
print(train)

train['Timestamp'] = pd.to_datetime(train['Timestamp'], unit='s') 
train.set_index('Timestamp', inplace=True)
print(train)

# Calcular la media por hora y rellenar posibles nulos
data_hour = train['Close'].resample('d').mean().ffill()

# Visualizamos la serie completa
data_hour.plot()
plt.show()
# Out:
# (6750281, 6)
#          Timestamp     Open     High      Low    Close    Volume
# 6750280        NaN  57854.0  57864.0  57835.0  57835.0  1.353466
#             Timestamp       Open       High        Low      Close    Volume
# 0        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 1        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 2        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 3        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 4        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# ...               ...        ...        ...        ...        ...       ...
# 6750275  1.737936e+09  102518.00  102559.00  102506.00  102558.00  0.771165
# 6750276  1.737936e+09  102628.00  102669.00  102608.00  102611.00  0.086742
# 6750277  1.737936e+09  102659.00  102712.00  102657.00  102712.00  0.488757
# 6750278  1.737936e+09  102631.00  102631.00  102573.00  102573.00  0.126719
# 6750279  1.737936e+09  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 6 columns]
#                           Open       High        Low      Close    Volume
# Timestamp
# 2012-01-01 10:01:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:02:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:03:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:04:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:05:00       4.58       4.58       4.58       4.58  0.000000
# ...                        ...        ...        ...        ...       ...
# 2025-01-26 23:56:00  102518.00  102559.00  102506.00  102558.00  0.771165
# 2025-01-26 23:57:00  102628.00  102669.00  102608.00  102611.00  0.086742
# 2025-01-26 23:58:00  102659.00  102712.00  102657.00  102712.00  0.488757
# 2025-01-26 23:59:00  102631.00  102631.00  102573.00  102573.00  0.126719
# 2025-01-27 00:00:00  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 5 columns]

# %%
# 1 año a considerar en el conjunto de test
n_steps = 365

# Dividimos la serie en train y test
train_size = len(data_hour) - n_steps
train, test = data_hour[:train_size], data_hour[train_size:]

# %%
train_log = np.log(train)

# %%
# Aplicar auto_arima para encontrar los mejores parámetros
m=52
modelo_auto_arima = auto_arima(train_log, start_p=1, start_q=1, max_p=20, max_q=20, max_order=60,
                         seasonal=False, stepwise=True, trace=True, error_action='ignore',
                         m=52, suppress_warnings=True)

# Mostrar resumen del modelo seleccionado
print(modelo_auto_arima.summary())
# Out:
# C:\Users\g3rm4\anaconda3\Lib\site-packages\pmdarima\arima\_validation.py:62: UserWarning: m (52) set for non-seasonal fit. Setting to 0
#   warnings.warn("m (%i) set for non-seasonal fit. Setting to 0" % m)
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=-16808.504, Time=1.75 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-16624.386, Time=0.69 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-16791.404, Time=0.36 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-16809.952, Time=0.74 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-16612.438, Time=0.24 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=-16808.852, Time=0.97 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=-16808.362, Time=1.23 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=-16801.971, Time=0.35 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0] intercept
# Total fit time: 6.352 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4411
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                8407.976
# Date:                Sun, 11 May 2025   AIC                         -16809.952
# Time:                        21:08:05   BIC                         -16790.778
# Sample:                    01-01-2012   HQIC                        -16803.189
#                          - 01-28-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0021      0.001      3.001      0.003       0.001       0.003
# ma.L1          0.2116      0.003     63.323      0.000       0.205       0.218
# sigma2         0.0013   6.69e-06    193.315      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):            206104.23
# Prob(Q):                              0.83   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.39   Skew:                            -1.16
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Ajustamos el modelo ARIMA
forecast = modelo_auto_arima.predict(n_steps)
forecast = np.exp(forecast)
forecast_index = test.index

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo ARIMA')
plt.savefig("Forecast_log_ARIMA_monthly.png")
plt.show()

# Evaluación del modelo
mae  = mean_absolute_error(test, forecast)
mape = mean_absolute_percentage_error(test, forecast) * 100
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 10490.24
# MAPE: 14.65%

# %%
del modelo_auto_arima       # elimina la referencia al objeto

# %%
modelo_auto_sarimax = auto_arima(train_log, start_p=1, start_q=1, max_p=20, max_q=20, max_order=60,
                         seasonal=True, stepwise=True, trace=True, error_action='ignore',
                         m=52, suppress_warnings=True)

# Mostrar resumen del modelo seleccionado
print(modelo_auto_sarimax.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[52] intercept   : AIC=-16808.587, Time=31.14 sec
#  ARIMA(0,1,0)(0,0,0)[52] intercept   : AIC=-16624.386, Time=0.70 sec
#  ARIMA(1,1,0)(1,0,0)[52] intercept   : AIC=-16793.416, Time=19.10 sec
#  ARIMA(0,1,1)(0,0,1)[52] intercept   : AIC=-16811.966, Time=7.65 sec
#  ARIMA(0,1,0)(0,0,0)[52]             : AIC=-16612.438, Time=0.28 sec
#  ARIMA(0,1,1)(0,0,0)[52] intercept   : AIC=-16809.952, Time=0.73 sec
#  ARIMA(0,1,1)(1,0,1)[52] intercept   : AIC=-16809.970, Time=8.69 sec
#  ARIMA(0,1,1)(0,0,2)[52] intercept   : AIC=-16810.048, Time=65.86 sec
#  ARIMA(0,1,1)(1,0,0)[52] intercept   : AIC=-16811.971, Time=7.37 sec
#  ARIMA(0,1,1)(2,0,0)[52] intercept   : AIC=-16810.046, Time=80.75 sec
#  ARIMA(0,1,1)(2,0,1)[52] intercept   : AIC=-16808.046, Time=91.92 sec
#  ARIMA(0,1,0)(1,0,0)[52] intercept   : AIC=-16625.834, Time=11.85 sec
#  ARIMA(1,1,1)(1,0,0)[52] intercept   : AIC=-16810.590, Time=35.12 sec
#  ARIMA(0,1,2)(1,0,0)[52] intercept   : AIC=-16810.940, Time=24.36 sec
#  ARIMA(1,1,2)(1,0,0)[52] intercept   : AIC=-16810.479, Time=23.32 sec
#  ARIMA(0,1,1)(1,0,0)[52]             : AIC=-16804.741, Time=4.50 sec
#
# Best model:  ARIMA(0,1,1)(1,0,0)[52] intercept
# Total fit time: 413.372 seconds
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                 4411
# Model:             SARIMAX(0, 1, 1)x(1, 0, [], 52)   Log Likelihood                8409.985
# Date:                             Sun, 11 May 2025   AIC                         -16811.971
# Time:                                     21:15:02   BIC                         -16786.404
# Sample:                                 01-01-2012   HQIC                        -16802.953
#                                       - 01-28-2024
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0020      0.001      2.877      0.004       0.001       0.003
# ma.L1          0.2079      0.004     58.699      0.000       0.201       0.215
# ar.S.L52       0.0311      0.017      1.881      0.060      -0.001       0.063
# sigma2         0.0013   6.76e-06    190.901      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            206826.72
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.39   Skew:                            -1.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                        36.46
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
forecast = modelo_auto_sarimax.predict(n_steps)
forecast = np.exp(forecast)
forecast_index = test.index

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast_sarimax, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo SARIMAX')
plt.savefig("Forecast_log_SARIMAX_monthly.png")
plt.show()

# Evaluación del modelo
mae  = mean_absolute_error(test, forecast)
mape = mean_absolute_percentage_error(test, forecast) * 100
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# MAE: 10587.23
# MAPE: 14.75%
