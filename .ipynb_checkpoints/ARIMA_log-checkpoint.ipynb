# %%
import pandas as pd
import numpy as np
import sklearn.preprocessing as prep
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima
# Cargamos el csv
train = pd.read_csv('btcusd_1-min_data.csv')

print(train.shape)

# Mostramos 10 registros al azar
train.sample(10)

#miro donde hay nulls si los hay
train.isna().sum()

filas_con_nulos = train[train.isnull().any(axis=1)]
print(filas_con_nulos)

train = train.dropna()
print(train)

train['Timestamp'] = pd.to_datetime(train['Timestamp'], unit='s') 
train.set_index('Timestamp', inplace=True)
print(train)

# Calcular la media por hora y rellenar posibles nulos
data_hour = train['Close'].resample('d').mean().ffill()

# Visualizamos la serie completa
data_hour.plot()
plt.show()
# Out:
# (6750281, 6)
#          Timestamp     Open     High      Low    Close    Volume
# 6750280        NaN  57854.0  57864.0  57835.0  57835.0  1.353466
#             Timestamp       Open       High        Low      Close    Volume
# 0        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 1        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 2        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 3        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 4        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# ...               ...        ...        ...        ...        ...       ...
# 6750275  1.737936e+09  102518.00  102559.00  102506.00  102558.00  0.771165
# 6750276  1.737936e+09  102628.00  102669.00  102608.00  102611.00  0.086742
# 6750277  1.737936e+09  102659.00  102712.00  102657.00  102712.00  0.488757
# 6750278  1.737936e+09  102631.00  102631.00  102573.00  102573.00  0.126719
# 6750279  1.737936e+09  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 6 columns]
#                           Open       High        Low      Close    Volume
# Timestamp
# 2012-01-01 10:01:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:02:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:03:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:04:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:05:00       4.58       4.58       4.58       4.58  0.000000
# ...                        ...        ...        ...        ...       ...
# 2025-01-26 23:56:00  102518.00  102559.00  102506.00  102558.00  0.771165
# 2025-01-26 23:57:00  102628.00  102669.00  102608.00  102611.00  0.086742
# 2025-01-26 23:58:00  102659.00  102712.00  102657.00  102712.00  0.488757
# 2025-01-26 23:59:00  102631.00  102631.00  102573.00  102573.00  0.126719
# 2025-01-27 00:00:00  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 5 columns]

# %%
# 1 año a considerar en el conjunto de test
n_steps = 365

# Dividimos la serie en train y test
train_size = len(data_hour) - n_steps
train, test = data_hour[:train_size], data_hour[train_size:]

# %%
# Aplicar auto_arima para encontrar los mejores parámetros
m=12 #(patrón mensual)
modelo_auto = auto_arima(train, start_p=1, start_q=1, max_p=20, max_q=20, max_order=60,
                         seasonal=True, stepwise=True, trace=True, error_action='ignore',
                         m=12, suppress_warnings=True)

# Mostrar resumen del modelo seleccionado
print(modelo_auto.summary())

# Obtener los parámetros óptimos
p, d, q = modelo_auto.order
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=5.04 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=68552.692, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=68391.686, Time=0.71 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=68390.730, Time=0.62 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=68551.920, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=68388.930, Time=0.26 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=68390.725, Time=0.97 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=3.72 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=68389.209, Time=1.01 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=68388.604, Time=0.39 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=68390.411, Time=0.89 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=68390.415, Time=0.83 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=4.33 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=68381.278, Time=2.25 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=68383.109, Time=4.09 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=68383.111, Time=3.53 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=7.58 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=68379.369, Time=2.66 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=68381.316, Time=5.50 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=68381.316, Time=5.97 sec
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=9.96 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=68390.191, Time=1.52 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=68346.721, Time=4.49 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=68348.442, Time=13.23 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=68348.463, Time=9.92 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=12.74 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=68382.901, Time=1.74 sec
#  ARIMA(4,1,2)(0,0,0)[12] intercept   : AIC=68375.553, Time=3.05 sec
#  ARIMA(3,1,3)(0,0,0)[12] intercept   : AIC=68378.999, Time=3.98 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=68379.318, Time=4.52 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=68373.747, Time=1.88 sec
#  ARIMA(4,1,3)(0,0,0)[12] intercept   : AIC=68345.807, Time=5.66 sec
#  ARIMA(4,1,3)(1,0,0)[12] intercept   : AIC=68347.451, Time=13.30 sec
#  ARIMA(4,1,3)(0,0,1)[12] intercept   : AIC=68347.709, Time=9.67 sec
#  ARIMA(4,1,3)(1,0,1)[12] intercept   : AIC=68349.709, Time=11.78 sec
#  ARIMA(5,1,3)(0,0,0)[12] intercept   : AIC=68349.084, Time=7.17 sec
#  ARIMA(4,1,4)(0,0,0)[12] intercept   : AIC=68347.285, Time=7.39 sec
#  ARIMA(3,1,4)(0,0,0)[12] intercept   : AIC=68344.523, Time=7.09 sec
#  ARIMA(3,1,4)(1,0,0)[12] intercept   : AIC=68345.913, Time=11.81 sec
#  ARIMA(3,1,4)(0,0,1)[12] intercept   : AIC=68345.921, Time=11.26 sec
#  ARIMA(3,1,4)(1,0,1)[12] intercept   : AIC=68348.436, Time=19.35 sec
#  ARIMA(2,1,4)(0,0,0)[12] intercept   : AIC=68346.701, Time=6.13 sec
#  ARIMA(3,1,5)(0,0,0)[12] intercept   : AIC=68347.965, Time=5.74 sec
#  ARIMA(2,1,5)(0,0,0)[12] intercept   : AIC=68348.182, Time=8.47 sec
#  ARIMA(4,1,5)(0,0,0)[12] intercept   : AIC=68350.108, Time=8.59 sec
#  ARIMA(3,1,4)(0,0,0)[12]             : AIC=68343.020, Time=3.42 sec
#  ARIMA(3,1,4)(1,0,0)[12]             : AIC=68344.487, Time=6.33 sec
#  ARIMA(3,1,4)(0,0,1)[12]             : AIC=68344.542, Time=6.52 sec
#  ARIMA(3,1,4)(1,0,1)[12]             : AIC=68347.128, Time=8.37 sec
#  ARIMA(2,1,4)(0,0,0)[12]             : AIC=68345.480, Time=2.97 sec
#  ARIMA(3,1,3)(0,0,0)[12]             : AIC=68376.342, Time=1.84 sec
#  ARIMA(4,1,4)(0,0,0)[12]             : AIC=68346.354, Time=2.77 sec
#  ARIMA(3,1,5)(0,0,0)[12]             : AIC=68344.699, Time=4.38 sec
#  ARIMA(2,1,3)(0,0,0)[12]             : AIC=68377.769, Time=1.94 sec
#  ARIMA(2,1,5)(0,0,0)[12]             : AIC=68346.981, Time=3.41 sec
#  ARIMA(4,1,3)(0,0,0)[12]             : AIC=68344.254, Time=3.40 sec
#  ARIMA(4,1,5)(0,0,0)[12]             : AIC=68349.983, Time=2.04 sec
#
# Best model:  ARIMA(3,1,4)(0,0,0)[12]
# Total fit time: 298.459 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4411
# Model:               SARIMAX(3, 1, 4)   Log Likelihood              -34163.510
# Date:                Sat, 29 Mar 2025   AIC                          68343.020
# Time:                        16:16:21   BIC                          68394.153
# Sample:                    01-01-2012   HQIC                         68361.055
#                          - 01-28-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1842      0.072      2.571      0.010       0.044       0.325
# ar.L2         -0.4601      0.056     -8.215      0.000      -0.570      -0.350
# ar.L3         -0.5901      0.069     -8.544      0.000      -0.725      -0.455
# ma.L1          0.0099      0.070      0.140      0.889      -0.128       0.148
# ma.L2          0.4373      0.047      9.270      0.000       0.345       0.530
# ma.L3          0.6379      0.060     10.712      0.000       0.521       0.755
# ma.L4          0.1687      0.011     15.296      0.000       0.147       0.190
# sigma2      3.168e+05   1912.650    165.646      0.000    3.13e+05    3.21e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            118241.58
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):            3588.60   Skew:                            -0.76
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.32
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Ajustamos el modelo ARIMA

forecast = modelo_auto.predict(n_steps)
forecast_index = test.index

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo ARIMA')
plt.savefig("Forecast_ARIMA_monthly.png")
plt.show()

# Evaluación del modelo
mae = mean_absolute_error(test, forecast)
print(f'Mean Absolute Error: {mae}')
mape = mean_absolute_percentage_error(test, forecast)
print(f'Mean Absolute Error: {mape}')
# Out:
# Mean Absolute Error: 27782.45202164365
# Mean Absolute Error: 0.36857060081809473

# %%
model = SARIMAX(train, order=(p, d, q), seasonal_order=(p, d, q, m))
fitted_model = model.fit()

# Forecast
forecast = fitted_model.forecast(steps=n_steps)
forecast_index = test.index
# Out:
# C:\Users\g3rm4\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo SARIMAX')
plt.savefig("Forecast_SARIMAX_monthly.png")
plt.show()

# Evaluación del modelo
mae = mean_absolute_error(test, forecast)
print(f'Mean Absolute Error: {mae}')
mape = mean_absolute_percentage_error(test, forecast)
print(f'Mean Absolute Error: {mape}')
# Out:
# Mean Absolute Error: 25080.192473214407
# Mean Absolute Error: 0.3315072910891533
