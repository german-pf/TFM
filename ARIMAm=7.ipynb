# %%
import pandas as pd
import numpy as np
import sklearn.preprocessing as prep
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima
# Cargamos el csv
train = pd.read_csv('btcusd_1-min_data.csv')

print(train.shape)

# Mostramos 10 registros al azar
train.sample(10)

#miro donde hay nulls si los hay
train.isna().sum()

filas_con_nulos = train[train.isnull().any(axis=1)]
print(filas_con_nulos)

train = train.dropna()
print(train)

train['Timestamp'] = pd.to_datetime(train['Timestamp'], unit='s') 
train.set_index('Timestamp', inplace=True)
print(train)

# Calcular la media por hora y rellenar posibles nulos
data_hour = train['Close'].resample('d').mean().ffill()

# Visualizamos la serie completa
data_hour.plot()
plt.show()
# Out:
# (6750281, 6)
#          Timestamp     Open     High      Low    Close    Volume
# 6750280        NaN  57854.0  57864.0  57835.0  57835.0  1.353466
#             Timestamp       Open       High        Low      Close    Volume
# 0        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 1        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 2        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 3        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 4        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# ...               ...        ...        ...        ...        ...       ...
# 6750275  1.737936e+09  102518.00  102559.00  102506.00  102558.00  0.771165
# 6750276  1.737936e+09  102628.00  102669.00  102608.00  102611.00  0.086742
# 6750277  1.737936e+09  102659.00  102712.00  102657.00  102712.00  0.488757
# 6750278  1.737936e+09  102631.00  102631.00  102573.00  102573.00  0.126719
# 6750279  1.737936e+09  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 6 columns]
#                           Open       High        Low      Close    Volume
# Timestamp
# 2012-01-01 10:01:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:02:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:03:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:04:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:05:00       4.58       4.58       4.58       4.58  0.000000
# ...                        ...        ...        ...        ...       ...
# 2025-01-26 23:56:00  102518.00  102559.00  102506.00  102558.00  0.771165
# 2025-01-26 23:57:00  102628.00  102669.00  102608.00  102611.00  0.086742
# 2025-01-26 23:58:00  102659.00  102712.00  102657.00  102712.00  0.488757
# 2025-01-26 23:59:00  102631.00  102631.00  102573.00  102573.00  0.126719
# 2025-01-27 00:00:00  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 5 columns]

# %%
# 1 año a considerar en el conjunto de test
n_steps = 365

# Dividimos la serie en train y test
train_size = len(data_hour) - n_steps
train, test = data_hour[:train_size], data_hour[train_size:]

# %%
# Aplicar auto_arima para encontrar los mejores parámetros
m=7 #(patrón semanal)
modelo_auto = auto_arima(train,seasonal=True, stepwise=True, trace=True, error_action='ignore', m=7, suppress_warnings=True)

# Mostrar resumen del modelo seleccionado
print(modelo_auto.summary())

# Obtener los parámetros óptimos
p, d, q = modelo_auto.order
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=68393.829, Time=5.09 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=68567.255, Time=0.10 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=68401.191, Time=0.49 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=68400.695, Time=0.46 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=68566.479, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=68392.128, Time=3.83 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=68393.898, Time=2.70 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=68393.528, Time=7.02 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=68392.254, Time=3.59 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=68395.461, Time=7.63 sec
#  ARIMA(1,1,2)(0,0,1)[7] intercept   : AIC=68394.496, Time=3.61 sec
#  ARIMA(2,1,1)(0,0,1)[7] intercept   : AIC=68401.938, Time=2.90 sec
#  ARIMA(3,1,2)(0,0,1)[7] intercept   : AIC=68368.095, Time=10.86 sec
#  ARIMA(3,1,2)(0,0,0)[7] intercept   : AIC=68361.240, Time=6.92 sec
#  ARIMA(3,1,2)(1,0,0)[7] intercept   : AIC=68369.478, Time=10.26 sec
#  ARIMA(3,1,2)(1,0,1)[7] intercept   : AIC=68383.193, Time=11.24 sec
#  ARIMA(3,1,1)(0,0,0)[7] intercept   : AIC=68397.437, Time=2.00 sec
#  ARIMA(4,1,2)(0,0,0)[7] intercept   : AIC=68390.089, Time=3.57 sec
#  ARIMA(3,1,3)(0,0,0)[7] intercept   : AIC=68393.528, Time=4.69 sec
#  ARIMA(2,1,1)(0,0,0)[7] intercept   : AIC=68404.751, Time=1.74 sec
#  ARIMA(2,1,3)(0,0,0)[7] intercept   : AIC=68393.849, Time=3.78 sec
#  ARIMA(4,1,1)(0,0,0)[7] intercept   : AIC=68388.297, Time=2.19 sec
#  ARIMA(4,1,3)(0,0,0)[7] intercept   : AIC=68360.325, Time=6.38 sec
#  ARIMA(4,1,3)(1,0,0)[7] intercept   : AIC=68362.085, Time=16.03 sec
#  ARIMA(4,1,3)(0,0,1)[7] intercept   : AIC=68362.112, Time=8.49 sec
#  ARIMA(4,1,3)(1,0,1)[7] intercept   : AIC=68364.278, Time=10.85 sec
#  ARIMA(5,1,3)(0,0,0)[7] intercept   : AIC=68363.723, Time=9.12 sec
#  ARIMA(4,1,4)(0,0,0)[7] intercept   : AIC=68362.290, Time=7.42 sec
#  ARIMA(3,1,4)(0,0,0)[7] intercept   : AIC=68358.904, Time=8.13 sec
#  ARIMA(3,1,4)(1,0,0)[7] intercept   : AIC=68360.904, Time=14.55 sec
#  ARIMA(3,1,4)(0,0,1)[7] intercept   : AIC=68361.061, Time=13.13 sec
#  ARIMA(3,1,4)(1,0,1)[7] intercept   : AIC=68362.966, Time=14.67 sec
#  ARIMA(2,1,4)(0,0,0)[7] intercept   : AIC=68361.232, Time=7.78 sec
#  ARIMA(3,1,5)(0,0,0)[7] intercept   : AIC=68362.469, Time=6.15 sec
#  ARIMA(2,1,5)(0,0,0)[7] intercept   : AIC=68362.712, Time=9.81 sec
#  ARIMA(4,1,5)(0,0,0)[7] intercept   : AIC=68364.908, Time=10.32 sec
#  ARIMA(3,1,4)(0,0,0)[7]             : AIC=68357.516, Time=3.46 sec
#  ARIMA(3,1,4)(1,0,0)[7]             : AIC=68359.523, Time=5.89 sec
#  ARIMA(3,1,4)(0,0,1)[7]             : AIC=68359.522, Time=6.05 sec
#  ARIMA(3,1,4)(1,0,1)[7]             : AIC=68361.526, Time=6.39 sec
#  ARIMA(2,1,4)(0,0,0)[7]             : AIC=68360.006, Time=4.43 sec
#  ARIMA(3,1,3)(0,0,0)[7]             : AIC=68390.862, Time=2.24 sec
#  ARIMA(4,1,4)(0,0,0)[7]             : AIC=68360.896, Time=3.65 sec
#  ARIMA(3,1,5)(0,0,0)[7]             : AIC=68361.023, Time=3.19 sec
#  ARIMA(2,1,3)(0,0,0)[7]             : AIC=68392.297, Time=1.92 sec
#  ARIMA(2,1,5)(0,0,0)[7]             : AIC=68361.519, Time=3.42 sec
#  ARIMA(4,1,3)(0,0,0)[7]             : AIC=68358.957, Time=3.12 sec
#  ARIMA(4,1,5)(0,0,0)[7]             : AIC=68361.911, Time=4.71 sec
#
# Best model:  ARIMA(3,1,4)(0,0,0)[7]
# Total fit time: 286.106 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4412
# Model:               SARIMAX(3, 1, 4)   Log Likelihood              -34170.758
# Date:                Mon, 17 Mar 2025   AIC                          68357.516
# Time:                        18:29:56   BIC                          68408.651
# Sample:                    01-01-2012   HQIC                         68375.552
#                          - 01-29-2024
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1842      0.072      2.551      0.011       0.043       0.326
# ar.L2         -0.4594      0.056     -8.139      0.000      -0.570      -0.349
# ar.L3         -0.5893      0.070     -8.472      0.000      -0.726      -0.453
# ma.L1          0.0091      0.071      0.129      0.898      -0.130       0.148
# ma.L2          0.4362      0.048      9.173      0.000       0.343       0.529
# ma.L3          0.6371      0.060     10.619      0.000       0.519       0.755
# ma.L4          0.1679      0.011     15.156      0.000       0.146       0.190
# sigma2      3.168e+05   1913.088    165.572      0.000    3.13e+05    3.21e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):            118431.95
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):            3588.67   Skew:                            -0.76
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Ajustamos el modelo ARIMA
model = ARIMA(train, order=(p,d,q)) #poner p d y q en caso de ejecutar auto_arima
fitted_model = model.fit()

# Forecast
forecast = fitted_model.forecast(steps=n_steps)
forecast_index = test.index

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo ARIMA')
plt.show()

# Evaluación del modelo
mae = mean_absolute_error(test, forecast)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 27934.39469765711

# %%
model = SARIMAX(train, order=(p, d, q), seasonal_order=(p, d, q, m))
fitted_model = model.fit()

# Forecast
forecast = fitted_model.forecast(steps=n_steps)
forecast_index = test.index
# Out:
# C:\Users\g3rm4\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo SARIMAX')
plt.show()

# Evaluación del modelo
mae = mean_absolute_error(test, forecast)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 26144.823638828082
