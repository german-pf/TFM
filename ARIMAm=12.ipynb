# %%
import pandas as pd
import numpy as np
import sklearn.preprocessing as prep
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pmdarima import auto_arima
# Cargamos el csv
train = pd.read_csv('btcusd_1-min_data.csv')

print(train.shape)

# Mostramos 10 registros al azar
train.sample(10)

#miro donde hay nulls si los hay
train.isna().sum()

filas_con_nulos = train[train.isnull().any(axis=1)]
print(filas_con_nulos)

train = train.dropna()
print(train)

train['Timestamp'] = pd.to_datetime(train['Timestamp'], unit='s') 
train.set_index('Timestamp', inplace=True)
print(train)

# Calcular la media por hora y rellenar posibles nulos
data_hour = train['Close'].resample('d').mean().ffill()

# Visualizamos la serie completa
data_hour.plot()
plt.show()
# Out:
# (6750281, 6)
#          Timestamp     Open     High      Low    Close    Volume
# 6750280        NaN  57854.0  57864.0  57835.0  57835.0  1.353466
#             Timestamp       Open       High        Low      Close    Volume
# 0        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 1        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 2        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 3        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# 4        1.325412e+09       4.58       4.58       4.58       4.58  0.000000
# ...               ...        ...        ...        ...        ...       ...
# 6750275  1.737936e+09  102518.00  102559.00  102506.00  102558.00  0.771165
# 6750276  1.737936e+09  102628.00  102669.00  102608.00  102611.00  0.086742
# 6750277  1.737936e+09  102659.00  102712.00  102657.00  102712.00  0.488757
# 6750278  1.737936e+09  102631.00  102631.00  102573.00  102573.00  0.126719
# 6750279  1.737936e+09  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 6 columns]
#                           Open       High        Low      Close    Volume
# Timestamp
# 2012-01-01 10:01:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:02:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:03:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:04:00       4.58       4.58       4.58       4.58  0.000000
# 2012-01-01 10:05:00       4.58       4.58       4.58       4.58  0.000000
# ...                        ...        ...        ...        ...       ...
# 2025-01-26 23:56:00  102518.00  102559.00  102506.00  102558.00  0.771165
# 2025-01-26 23:57:00  102628.00  102669.00  102608.00  102611.00  0.086742
# 2025-01-26 23:58:00  102659.00  102712.00  102657.00  102712.00  0.488757
# 2025-01-26 23:59:00  102631.00  102631.00  102573.00  102573.00  0.126719
# 2025-01-27 00:00:00  102573.00  102604.00  102507.00  102514.00  0.474495
#
# [6750280 rows x 5 columns]

# %%
# 1 año a considerar en el conjunto de test
n_steps = 364

# Dividimos la serie en train y test
train_size = len(data_hour) - n_steps
train, test = data_hour[:train_size], data_hour[train_size:]

# %%
# Aplicar auto_arima para encontrar los mejores parámetros
m=12
modelo_auto = auto_arima(train,seasonal=True, stepwise=True, trace=True, error_action='ignore', m=12 , suppress_warnings=True)


# Mostrar resumen del modelo seleccionado
print(modelo_auto.summary())

# Obtener los parámetros óptimos
p, d, q = modelo_auto.order
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=9.13 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=68567.255, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=68406.281, Time=0.63 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=68405.284, Time=0.59 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=68566.479, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=68403.484, Time=0.25 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=68405.280, Time=0.57 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=2.91 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=68403.779, Time=1.00 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=68403.179, Time=0.31 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=68404.986, Time=0.76 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=68404.990, Time=0.76 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=3.45 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=68395.831, Time=1.47 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=68397.661, Time=3.51 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=68397.663, Time=3.32 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=5.96 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=68393.898, Time=2.15 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=68395.845, Time=4.93 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=68395.845, Time=4.79 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=68404.751, Time=1.32 sec
#  ARIMA(3,1,2)(0,0,0)[12] intercept   : AIC=68361.240, Time=4.64 sec
#  ARIMA(3,1,2)(1,0,0)[12] intercept   : AIC=68362.964, Time=9.60 sec
#  ARIMA(3,1,2)(0,0,1)[12] intercept   : AIC=68362.985, Time=7.74 sec
#  ARIMA(3,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=11.13 sec
#  ARIMA(3,1,1)(0,0,0)[12] intercept   : AIC=68397.437, Time=1.48 sec
#  ARIMA(4,1,2)(0,0,0)[12] intercept   : AIC=68390.089, Time=2.42 sec
#  ARIMA(3,1,3)(0,0,0)[12] intercept   : AIC=68393.528, Time=3.57 sec
#  ARIMA(2,1,3)(0,0,0)[12] intercept   : AIC=68393.849, Time=2.69 sec
#  ARIMA(4,1,1)(0,0,0)[12] intercept   : AIC=68388.297, Time=1.61 sec
#  ARIMA(4,1,3)(0,0,0)[12] intercept   : AIC=68360.325, Time=4.50 sec
#  ARIMA(4,1,3)(1,0,0)[12] intercept   : AIC=68362.193, Time=9.69 sec
#  ARIMA(4,1,3)(0,0,1)[12] intercept   : AIC=68361.883, Time=12.80 sec
#  ARIMA(4,1,3)(1,0,1)[12] intercept   : AIC=68357.659, Time=13.09 sec
#  ARIMA(4,1,3)(2,0,1)[12] intercept   : AIC=68354.505, Time=31.23 sec
#  ARIMA(4,1,3)(2,0,0)[12] intercept   : AIC=68358.170, Time=28.88 sec
#  ARIMA(4,1,3)(2,0,2)[12] intercept   : AIC=68358.095, Time=31.63 sec
#  ARIMA(4,1,3)(1,0,2)[12] intercept   : AIC=68354.127, Time=31.04 sec
#  ARIMA(4,1,3)(0,0,2)[12] intercept   : AIC=68358.698, Time=29.31 sec
#  ARIMA(3,1,3)(1,0,2)[12] intercept   : AIC=inf, Time=25.61 sec
#  ARIMA(4,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=23.03 sec
#  ARIMA(5,1,3)(1,0,2)[12] intercept   : AIC=68358.764, Time=29.78 sec
#  ARIMA(4,1,4)(1,0,2)[12] intercept   : AIC=68358.845, Time=32.03 sec
#  ARIMA(3,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=21.60 sec
#  ARIMA(3,1,4)(1,0,2)[12] intercept   : AIC=68354.428, Time=33.30 sec
#  ARIMA(5,1,2)(1,0,2)[12] intercept   : AIC=inf, Time=19.58 sec
#  ARIMA(5,1,4)(1,0,2)[12] intercept   : AIC=68351.321, Time=34.15 sec
#  ARIMA(5,1,4)(0,0,2)[12] intercept   : AIC=68354.791, Time=34.13 sec
#  ARIMA(5,1,4)(1,0,1)[12] intercept   : AIC=68356.803, Time=16.96 sec
#  ARIMA(5,1,4)(2,0,2)[12] intercept   : AIC=68353.821, Time=41.39 sec
#  ARIMA(5,1,4)(0,0,1)[12] intercept   : AIC=68356.260, Time=15.17 sec
#  ARIMA(5,1,4)(2,0,1)[12] intercept   : AIC=68350.845, Time=36.88 sec
#  ARIMA(5,1,4)(2,0,0)[12] intercept   : AIC=68354.865, Time=30.97 sec
#  ARIMA(5,1,4)(1,0,0)[12] intercept   : AIC=68354.234, Time=14.88 sec
#  ARIMA(4,1,4)(2,0,1)[12] intercept   : AIC=68357.589, Time=32.79 sec
#  ARIMA(5,1,3)(2,0,1)[12] intercept   : AIC=68358.390, Time=32.34 sec
#  ARIMA(5,1,5)(2,0,1)[12] intercept   : AIC=68342.564, Time=37.49 sec
#  ARIMA(5,1,5)(1,0,1)[12] intercept   : AIC=68352.397, Time=18.20 sec
#  ARIMA(5,1,5)(2,0,0)[12] intercept   : AIC=68343.640, Time=34.94 sec
#  ARIMA(5,1,5)(2,0,2)[12] intercept   : AIC=68344.191, Time=40.98 sec
#  ARIMA(5,1,5)(1,0,0)[12] intercept   : AIC=68352.678, Time=15.95 sec
#  ARIMA(5,1,5)(1,0,2)[12] intercept   : AIC=68341.632, Time=40.20 sec
#  ARIMA(5,1,5)(0,0,2)[12] intercept   : AIC=68344.466, Time=33.61 sec
#  ARIMA(5,1,5)(0,0,1)[12] intercept   : AIC=68354.337, Time=17.00 sec
#  ARIMA(4,1,5)(1,0,2)[12] intercept   : AIC=68359.201, Time=36.02 sec
#  ARIMA(5,1,5)(1,0,2)[12]             : AIC=68343.614, Time=15.35 sec
#
# Best model:  ARIMA(5,1,5)(1,0,2)[12] intercept
# Total fit time: 1049.359 seconds
#                                         SARIMAX Results
# ===============================================================================================
# Dep. Variable:                                       y   No. Observations:                 4412
# Model:             SARIMAX(5, 1, 5)x(1, 0, [1, 2], 12)   Log Likelihood              -34155.816
# Date:                                 Mon, 17 Mar 2025   AIC                          68341.632
# Time:                                         15:42:29   BIC                          68437.510
# Sample:                                     01-01-2012   HQIC                         68375.450
#                                           - 01-29-2024
# Covariance Type:                                   opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      7.7247     37.590      0.206      0.837     -65.949      81.399
# ar.L1         -0.1476      0.041     -3.620      0.000      -0.228      -0.068
# ar.L2         -0.5378      0.025    -21.454      0.000      -0.587      -0.489
# ar.L3         -0.2827      0.031     -8.978      0.000      -0.344      -0.221
# ar.L4         -0.5997      0.029    -20.781      0.000      -0.656      -0.543
# ar.L5          0.3921      0.032     12.161      0.000       0.329       0.455
# ma.L1          0.3380      0.043      7.846      0.000       0.254       0.422
# ma.L2          0.6066      0.028     21.467      0.000       0.551       0.662
# ma.L3          0.3755      0.034     10.967      0.000       0.308       0.443
# ma.L4          0.7301      0.030     24.723      0.000       0.672       0.788
# ma.L5         -0.2588      0.037     -6.947      0.000      -0.332      -0.186
# ar.S.L12      -0.5159      0.106     -4.858      0.000      -0.724      -0.308
# ma.S.L12       0.4963      0.106      4.694      0.000       0.289       0.704
# ma.S.L24       0.0370      0.009      4.203      0.000       0.020       0.054
# sigma2      3.152e+05   2064.591    152.652      0.000    3.11e+05    3.19e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.29   Jarque-Bera (JB):            106653.55
# Prob(Q):                              0.59   Prob(JB):                         0.00
# Heteroskedasticity (H):            3516.32   Skew:                            -0.67
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.05
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Ajustamos el modelo ARIMA
model = ARIMA(train, order=(p,d,q)) #poner p d y q en caso de ejecutar auto_arima
fitted_model = model.fit()

# Forecast
forecast = fitted_model.forecast(steps=n_steps)
forecast_index = test.index
# Out:
# C:\Users\g3rm4\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo ARIMA')
plt.show()

# Evaluación del modelo
mae = mean_absolute_error(test, forecast)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 27894.494687083392

# %%
model = SARIMAX(train, order=(p, d, q), seasonal_order=(p, d, q, m))
fitted_model = model.fit()

# Forecast
forecast = fitted_model.forecast(steps=n_steps)
forecast_index = test.index
# Out:
# C:\Users\g3rm4\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\g3rm4\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\g3rm4\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Visualizamos los resultados
plt.figure(figsize=(10, 6))
plt.plot(train, label='Serie original')
plt.plot(test.index, test, label='Conjunto de test', color='green')
plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.legend()
plt.title('Forecast del modelo SARIMAX')
plt.show()

# Evaluación del modelo
mae = mean_absolute_error(test, forecast)
print(f'Mean Absolute Error: {mae}')
# Out:
# Mean Absolute Error: 25226.227417988564
